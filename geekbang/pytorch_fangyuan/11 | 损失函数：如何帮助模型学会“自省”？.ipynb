# %% [markdown]
# 一个深度学习项目包括了模型的设计、损失函数的设计、梯度更新的方法、模型的保存与加载、模型的训练过程等几个主要模块。
# 损失函数是一把衡量模型学习效果的尺子，甚至可以说，训练模型的过程，实际就是优化损失函数的过程
#
# ![image.png](attachment:image.png)
#
#
# # 一个简单的例子

# %% [markdown]
# # 过拟合与欠拟合

# %% [markdown]
# # 损失函数与代价函数
#
# ## 常见损失函数
#
# ### 0-1 损失函数
#
# ### 平方损失函数
#
# ###  均方差损失函数和平均绝对误差损失函数
#
#     均方误差（Mean Squared Error，MSE）是回归问题损失函数中最常用的一个，也称作 L2 损失函数。
#
# ### 交叉熵损失函数
#
# ###  softmax 损失函数
#
# softmax 是深度学习中使用非常频繁的一个函数。在某些场景下，一些数值大小范围分布非常广，而为了方便计算，或者使梯度更好的更新（后续我们还会学习梯度更新），我们需要把输入的这些数值映射为 0-1 之间的实数，并且归一化后能够保证几个数的和为 1。

# %% [markdown]
# #

# %% [markdown]
# # 小结

# %% [markdown]
# # 每日一练

# %% [markdown]
# # QA

# %% [markdown]
# # todo
